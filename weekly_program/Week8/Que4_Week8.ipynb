# %%
import sys
import os

sys.argv = ['Que4_Week8.py' , 'untitled.txt']

def word_count(filename):
    if not os.path.isfile(filename):
        print(f"Error: '{filename}' does not exist.")
        return

    lines_count = 0
    charac_count = 0

    with open(filename, 'r') as file:
        for line in file:
            lines_count += 1
            charac_count += len(line) 

    print(f"Lines: {lines_count}")
    print(f"Characters: {charac_count}")

if __name__ == "__main__":
    if len(sys.argv) != 2:
        print("Please enter the file name")
    else:
        filename = sys.argv[1]
        word_count(filename)
# Out:
# Lines: 3
# Characters: 33
