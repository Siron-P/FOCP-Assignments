# %%
def encryption(word):
    word = word.replace(" ","")
    return word[::-1]

user_input = input("Enter any string : ")
print(f"The encryption of the word {user_input} will be {encryption(user_input)}")
# Out:
# Enter any string :  Siron
# The encryption of the word Siron will be noriS
