# %%
def factor_num(num):
    factors=[]
    for i in range(1,num+1):
        if num%i==0:
            factors.append(i)

    return factors
        
n = int(input("Enter any number for it's factor : "))
print(f"The factors of {n} are {factor_num(n)}")
# Out:
# Enter any number for it's factor :  7
# The factors of 7 are [1, 7]
