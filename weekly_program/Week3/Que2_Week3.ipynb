# %%
np = input("Enter new password: ")
p = input("Re-enter password for confirmation: ")

if np==p:
    print("Password set!")

else :
    print("Error! Please retry.")
# Out:
# Enter new password:  Sironaaron
# Re-enter password for confirmation:  Sironaaron
# Password set!
