# %%
print("Hello, what is your name?  ")
a = input()
count = len(a)

if count > 1:
    print(f"Hello, {a}. Good to meet you!")
else:
    print("Hello, Stranger!")
# Out:
# Hello, what is your name?
#  Siron
# Hello, Siron. Good to meet you!
