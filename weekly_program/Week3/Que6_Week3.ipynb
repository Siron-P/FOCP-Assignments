# %%
for i in range(0,13):
    ans = i * 7
    print(f"{i} X 7 = {ans}")
# Out:
# 0 X 7 = 0
# 1 X 7 = 7
# 2 X 7 = 14
# 3 X 7 = 21
# 4 X 7 = 28
# 5 X 7 = 35
# 6 X 7 = 42
# 7 X 7 = 49
# 8 X 7 = 56
# 9 X 7 = 63
# 10 X 7 = 70
# 11 X 7 = 77
# 12 X 7 = 84
