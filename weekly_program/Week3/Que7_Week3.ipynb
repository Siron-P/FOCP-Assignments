# %%
num = int(input("Enter the required number of table of 7 (0-12): ")) 
for i in range(num+1): 
    ans = i * 7 
    print(f"{i} X 7 = {ans}")
# Out:
# Enter the required number of table of 7 (0-12):  8
# 0 X 7 = 0
# 1 X 7 = 7
# 2 X 7 = 14
# 3 X 7 = 21
# 4 X 7 = 28
# 5 X 7 = 35
# 6 X 7 = 42
# 7 X 7 = 49
# 8 X 7 = 56
