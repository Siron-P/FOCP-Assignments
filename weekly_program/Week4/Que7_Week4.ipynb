# %%
def find():
    print("\nEnter any 6 temperatures in celsius : ")
    listt = []
    for i in range(0,6):
        temp = float(input(f"\nTemperature {i+1} : "))
        listt.append(temp)

    maximum = max(listt)
    print(f"\n Maximum value in the given temperatures = {maximum}")

    minimum = min(listt)
    print(f"\n Minimum value in the given temperatures = {minimum}")

    mean = sum(listt)/len(listt)
    print(f"\nMean of the given temperatures = {mean}\n")

find()
# Out:
# Enter any 6 temperatures in celsius :
# Temperature 1 :  20
#
# Temperature 2 :  30
#
# Temperature 3 :  20
#
# Temperature 4 :  30
#
# Temperature 5 :  20
#
# Temperature 6 :  30
#  Maximum value in the given temperatures = 30.0
#
#  Minimum value in the given temperatures = 20.0
#
# Mean of the given temperatures = 25.0
