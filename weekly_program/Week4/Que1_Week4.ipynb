# %%
def check_int(num):
    if num>=0 and num<=100:
        return True
    else:
        return False
    
n = int(input("Enter any integer: "))
print(check_int(n))
# Out:
# Enter any integer:  25
# True
