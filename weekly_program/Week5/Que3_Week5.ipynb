# %%
import sys

sys.argv = ['Que3_Week5.py', 'Pencil' , 'Pen' , 'Eraser' , 'Sharpner']

args = sys.argv[1:]

if not args:
    print("No arguments provided.")
else:
    args.sort(key=len)
    print(f"Shortest argument: {args[0]}")
# Out:
# Shortest argument: Pen
