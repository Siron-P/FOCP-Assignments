# %%
num_stud = int(input("Enter the number of students: "))
group_size = int(input("Enter the size of the group: "))

a = num_stud/group_size
a = int(a)
b = num_stud%group_size

print(f"There will be {a} groups and {b} students leftover.")
# Out:
# Enter the number of students:  24
# Enter the size of the group:  7
# There will be 3 groups and 3 students leftover.
