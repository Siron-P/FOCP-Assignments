# %%
no_sweets = int(input("number of sweets? "))
no_student = int(input("number of students? "))

sweet_each_pupil = no_sweets // no_student
leftover = no_sweets % no_student

print(f"Each pupil should get {sweet_each_pupil} sweets.")
print(f"She will have {leftover} leftover.")
# Out:
# number of sweets?  105
# number of students?  24
# Each pupil should get 4 sweets.
# She will have 9 leftover.
