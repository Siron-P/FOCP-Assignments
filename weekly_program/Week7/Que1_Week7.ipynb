# %%
def sort_unique(word):
    
    unique_sort = sorted(set(word))
    return unique_sort
    
word = list(input("Enter a word : "))
print(sort_unique(word))
# Out:
# Enter a word :  Siron
# ['S', 'i', 'n', 'o', 'r']
